# %%
from transformers import pipeline

card = "alex-miller/cdp-paf-meta-classifier"
classifier = pipeline("text-classification", model=card,
    # device=0
)

texts = [
    # PAF/AA
    "Central Emergency Response Fund Ensure protection of livelihoods and acceptable food consumption of vulnerable populations at risk of extreme food insecurity due to drought. VIII.1. Emergency Response Material relief assistance and services ODA Grants ENSURE PROTECTION OF LIVELIHOODS AND ACCEPTABLE FOOD CONSUMPTION OF VULNERABLE POPULATIONS AT RISK OF EXTREME FOOD INSECURITY DUE TO DROUGHT.",
    # PAF/AA
    "International Bank for Reconstruction and Development VIII.3. Disaster Prevention & Preparedness Multi-hazard response preparedness Other Official Flows (non Export Credit) COSTA RICA CATASTROPHE DEFERRED DRAW DOWN OPTION (CAT DDO)",
    # PAF/AA
    "EU Institutions Ending Drought Emergencies: Support to Pillar 5 (EDE/DRMC-SP5) VIII.3. Disaster Prevention & Preparedness Multi-hazard response preparedness ODA Grants ENDING DROUGHT EMERGENCIES: SUPPORT TO PILLAR 5 (EDE/DRMC-SP5) This grant will support one of the sixth pillars of the EDE CPF, namely the Drought Risk Management (Pillar 5), which is under the responsibility of the National Drought Management Authority (NDMA). Under the fifth pillar, the programme will support the component on early warning and early response to specifically strengthen the timeliness, accountability and efficiency of drought response, including through better preparedness.",
    # PAF/AA
    "Inter-American Development Bank Contingent Loan for Natural Disaster Emergencies II.4. Banking & Financial Services Financial policy and administrative management Other Official Flows (non Export Credit) CONTINGENT LOAN FOR NATURAL DISASTER EMERGENCIES Contingent Loan for Natural Disaster Emergencies",
    # Unrelated
    "Oak Foundation Research Foundation of the City University of New York VIII.1. Emergency Response Material relief assistance and services Private Development Finance RESEARCH FOUNDATION OF THE CITY UNIVERSITY OF NEW YORK Programme: Special Interest. Description: To help consolidate the presence and outreach of the Center for Immigrant, Refugee and Global Health (CIRGH) at City University of New York s School of Public Health (SPH). The central mission of the CIRGH is to advance scholarship, practice and understanding of the health and related challenges faced by immigrants and refugees at local, national and global levels.",
    # Unrelated
    "United Kingdom Support to the International Committee of the Red Cross (ICRC) in the Sahel during 2022 VIII.1. Emergency Response Material relief assistance and services ODA Grants SUPPORT TO THE INTERNATIONAL COMMITTEE OF THE RED CROSS (ICRC) IN THE SAHEL DURING 2022 To provide life-saving assistance to crisis-affected and vulnerable people across five Sahelian countries, Mali, Niger, Chad, Mauritania and Burkina Faso. This support includes assistance for those suffering from food insecurity, therapeutic food and early detection of severe acute malnutrition, basic support to livelihoods through the provision of seeds and tools, animal food and animal vaccinations, improved access to safe water and hygiene, and emergency health and medicine.",
    # Unrelated
    "United States Reconciliation Activity VIII.1. Emergency Response Material relief assistance and services ODA Grants RECONCILIATION ACTIVITY Reconciliation Activity"
]
classifier(texts)
# Out:
# config.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/673M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [{'label': 'PAF/AA', 'score': 0.9195141196250916},
#  {'label': 'PAF/AA', 'score': 0.8137043118476868},
#  {'label': 'PAF/AA', 'score': 0.8987476825714111},
#  {'label': 'PAF/AA', 'score': 0.9216814637184143},
#  {'label': 'Unrelated', 'score': 0.8043110370635986},
#  {'label': 'Unrelated', 'score': 0.9155363440513611},
#  {'label': 'Unrelated', 'score': 0.978498637676239}]
